# %% [markdown]
# ## Scraping of mobile phones' specifications from flipkart webpage

# %%
import requests
from bs4 import BeautifulSoup as bts
import pandas as pd

# %%
URL = "https://www.flipkart.com/search?q=mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off"
r = requests.get(URL)
htmlcontent = r.content
soup = bts(htmlcontent,'html.parser')
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE doctype html>
# ...

# %%
products = []
prices = []
ratings = []
memory = []
display = []
camera = []

# %%
for a in soup.findAll('a',href = True, attrs = {'class' : '_1fQZEK'}):
  name = a.find('div', attrs = {'class' : '_4rR01T'})
  price = a.find('div', attrs = {'class' : '_30jeq3 _1_WHN1'})
  rating = a.find('div', attrs = {'class' : '_3LWZlK'})
 
  for b in soup.findAll('div', attrs = {'class' : 'fMghEO'}):
    for k in soup.findAll('ul', attrs = {'class' : '_1xgFaf'}):
        mem = k.find_all('li', attrs = {'class' : 'rgWa7D'})[0]
        disp = k.find_all('li', attrs = {'class' : 'rgWa7D'})[1]
        cam = k.find_all('li', attrs = {'class' : 'rgWa7D'})[2]

        memory.append(mem.text)
        display.append(disp.text)
        camera.append(cam.text)
  
  products.append(name.text)
  prices.append(price.text)
  ratings.append(rating)

# %%
a = {'Product' : products, 'Price' : prices, 'Ratings' : ratings, 'Memory' : memory, 'Display' : display, 'Camera' : camera}
df = pd.DataFrame.from_dict(a, orient = 'index')
df

# %%
df.iloc[:,:6]
# Out:
#                                                      0  ...                                              5
# Product                  realme C20 (Cool Blue, 32 GB)  ...                   POCO C3 (Arctic Blue, 32 GB)
# Price                                           ₹7,499  ...                                         ₹7,349
# Ratings                                            4.4  ...                                            4.3
# Memory   2 GB RAM | 32 GB ROM | Expandable Upto 256 GB  ...  3 GB RAM | 32 GB ROM | Expandable Upto 512 GB
# Display                16.51 cm (6.5 inch) HD+ Display  ...               16.59 cm (6.53 inch) HD+ Display
# Camera              8MP Rear Camera | 5MP Front Camera  ...            13MP + 2MP + 2MP | 5MP Front Camera
#
# [6 rows x 6 columns]

# %%
df1 = df.transpose(copy = False)
df1.head()
# Out:
#                          Product  ...                               Camera
# 0  realme C20 (Cool Blue, 32 GB)  ...   8MP Rear Camera | 5MP Front Camera
# 1  realme C20 (Cool Grey, 32 GB)  ...   8MP Rear Camera | 5MP Front Camera
# 2   POCO C3 (Arctic Blue, 64 GB)  ...  13MP + 2MP + 2MP | 5MP Front Camera
# 3       I Kall Z3 (Green, 32 GB)  ...   8MP Rear Camera | 5MP Front Camera
# 4   POCO C3 (Matte Black, 64 GB)  ...  13MP + 2MP + 2MP | 5MP Front Camera
#
# [5 rows x 6 columns]
